# %%
from IPython.display import Image
Image(filename = "C:/Users/Win 10/Pictures/matrix.png", width = 600, height = 300)

# %% [markdown]
# #### IMPORT LIBRARIES

# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

# %% [markdown]
# #### IMPORT THE DATASETS

# %% [markdown]
# ##### CUSTOMER

# %%
customer=pd.read_csv('C:/Users/Win 10/Desktop/VIB/Track 1 Datarathon/1.Data_Customer.csv')
customer.head()
# Out:
#    CUSTOMER_NUMBER CLIENT_SEX CLIENT_CREATE_DATE        DATE_OF_BIRTH  \
# 0           639362          M         2019-04-23  1996-01-01 00:00:00
# 1           452440          M         2019-01-11  1999-10-10 00:00:00
# 2           326290          F         2019-05-27  1996-06-29 00:00:00
# 3            20802          M         2019-11-12  1992-08-07 00:00:00
# 4           114244          M         2019-03-29  1973-10-15 00:00:00
#
#   STAFF_VIB IB_REGISTER_DATE EB_REGISTER_CHANNEL SMS VERIFY_METHOD
# 0         N       2019-04-23              BRANCH   Y           SMS
# 1         N       2019-01-11              BRANCH   Y     SMART_OTP
# 2         N       2019-05-27              BRANCH   Y           SMS
# 3         N       2019-11-12              BRANCH   Y     SMART_OTP
# 4         N       2019-03-29              BRANCH   N           SMS

# %% [markdown]
# ##### TRANSACTION

# %%
transaction=pd.read_csv('C:/Users/Win 10/Desktop/VIB/Track 1 Datarathon/2.Data_MyVIB_Transaction.csv')
transaction.head()
# Out:
#   TRANS_LV1              TRANS_LV2  TRANS_DATE DAY_OF_WEEK  TRANS_HOUR  \
# 0  Transfer            Outside_VIB  2019-01-03         Thu          17
# 1  Transfer            Outside_VIB  2019-07-01         Mon          13
# 2  Transfer            Outside_VIB  2019-01-02         Wed          15
# 3   Payment  Credit_card_repayment  2019-01-03         Thu          14
# 4   Payment  Credit_card_repayment  2019-01-28         Mon          22
#
#    TRANS_NO  TRANS_AMOUNT  CUSTOMER_NUMBER
# 0         2   189771864.0           701619
# 1         2    30224900.0           701619
# 2         1      100000.0           701619
# 3         1    85000000.0           262123
# 4         1    83000000.0           262123

# %% [markdown]
# ##### ACTIVITY

# %%
activity=pd.read_csv('C:/Users/Win 10/Desktop/VIB/Track 1 Datarathon/3.Data_MyVIB_Activity.csv')
activity.head()
# Out:
#   ACTIVITY_DATE DAY_OF_WEEK  ACTIVITY_HOUR  ACTIVITY_NO  CUSTOMER_NUMBER  \
# 0     1/22/2019         Tue             20            2           630178
# 1     1/10/2019         Thu             18           16           630178
# 2     1/26/2019         Sat             17           15           630178
# 3      1/2/2019         Wed              9           27           630178
# 4     1/19/2019         Sat              8            3           630178
#
#            ACTIVITY_NAME
# 0  MB_INTEREST_RATE_VIEW
# 1  MB_INTEREST_RATE_VIEW
# 2  MB_INTEREST_RATE_VIEW
# 3  MB_INTEREST_RATE_VIEW
# 4  MB_INTEREST_RATE_VIEW

# %% [markdown]
# ##### DEPOSIT

# %%
deposit=pd.read_csv('C:/Users/Win 10/Desktop/VIB/Track 1 Datarathon/4.Data_Deposit.csv')
deposit.head()
# Out:
#        MONTH  COUNT_CA_ACCT  AVG_CA_BALANCE  COUNT_TD_ACCT  AVG_TD_BALANCE  \
# 0  1/31/2019              1       246774.19              0             0.0
# 1  2/28/2019              1       209207.36              0             0.0
# 2  3/31/2019              1       213225.90              0             0.0
# 3  4/30/2019              1       211761.87              0             0.0
# 4  5/31/2019              1       222391.16              0             0.0
#
#    CUSTOMER_NUMBER
# 0           914393
# 1           914393
# 2           914393
# 3           914393
# 4           914393

# %% [markdown]
# ##### LENDING

# %%
lending=pd.read_csv('C:/Users/Win 10/Desktop/VIB/Track 1 Datarathon/5.Data_Lending.csv')
lending.head()
# Out:
#        MONTH  COUNT_OF_LOAN  AVG_LOAN_AMOUNT  CUSTOMER_NUMBER
# 0  1/31/2019              1       15000000.0           811795
# 1  2/28/2019              1       13450000.0           811795
# 2  4/30/2019              1       14169673.0           811795
# 3  3/31/2019              1       12901665.0           811795
# 4  9/30/2019              1       13274815.0           811795

# %% [markdown]
# ##### CARD

# %%
card=pd.read_csv('C:/Users/Win 10/Desktop/VIB/Track 1 Datarathon/6.Data_Card.csv')
card.head()
# Out:
#         MONTH  COUNT_CREDITCARD  COUNT_DEBITCARD  CUSTOMER_NUMBER
# 0   9/30/2019                 0                1           914326
# 1   4/30/2019                 0                1           914326
# 2  11/30/2019                 0                1           914326
# 3   8/31/2019                 0                1           914326
# 4  12/31/2019                 0                1           914326
